# %% [markdown]
# # **A perceptron is is the smallest part of the neural network**
#
# ## perceptron is also called as artificial neuron
#
# ![Alt text](image_2.png)
#
# ## The above image shows a simple perceptron with 3 inputs

# %% [markdown]
# ## Lets mathematically represent what this percenptron means
# ### lets first put some facts about this perceptron
# - all input have assoicated weight with it
#
# #### so we have input as a vector which is [x1,x2,x3] for 3-input layer
# #### and asscoicated weight with this input is represented as [w1,w2,w3]

# %%
# lets write the in python to understand this 

import numpy as np

# %%
input_layer=np.array([[5,3,8]])
weights=np.array([[0.5],[0.5],[0.5]])

print(f"{np.dot(input_layer,weights)}")
print('''This is the result of the preceptron or output of the preceptron which either can be input to next perceptron or output to the 
world ''')
# Out:
# [[8.]]
# This is the result of the preceptron or output of the preceptron which either can be input to next perceptron or output to the
# world
